# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dataset =pd.read_csv('EEG_Eye_State.csv')
dataset
# Out:
#            AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0      4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1      4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2      4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3      4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4      4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
# 5      4321.03  4004.62  4284.10  4153.33  4345.64  4587.18  4093.33  4616.92
# 6      4319.49  4001.03  4280.51  4151.79  4343.59  4584.62  4089.74  4615.90
# 7      4325.64  4006.67  4278.46  4143.08  4344.10  4583.08  4087.18  4614.87
# 8      4326.15  4010.77  4276.41  4139.49  4345.13  4584.10  4091.28  4608.21
# 9      4326.15  4011.28  4276.92  4142.05  4344.10  4582.56  4092.82  4608.72
# 10     4326.15  4010.77  4272.82  4143.08  4342.56  4579.49  4087.69  4615.90
# ...

# %%
sns.set(style='whitegrid', context='notebook')
cols = ['AF3', 'F7', 'F3', 'FC5', 'T7','P7','O1','O2','P8','T8','FC6','F4','F8','AF4']
sns.pairplot(dataset[cols], size=2.5)
plt.show()

# %%
corr_matrix=dataset.corr(method='pearson')
print(corr_matrix)
# Out:
#                     AF3        F7        F3       FC5        T7        P7  \
# AF3            1.000000  0.364781  0.638665  0.012152  0.360134 -0.137153
# F7             0.364781  1.000000  0.672547 -0.281086  0.220783 -0.130520
# F3             0.638665  0.672547  1.000000 -0.435915  0.195539 -0.253306
# FC5            0.012152 -0.281086 -0.435915  1.000000  0.672908  0.829163
# T7             0.360134  0.220783  0.195539  0.672908  1.000000  0.798884
# P7            -0.137153 -0.130520 -0.253306  0.829163  0.798884  1.000000
# O1             0.006583 -0.284710 -0.439979  0.999973  0.671145  0.830410
# O2             0.072574  0.057324  0.290656  0.206797  0.579628  0.540435
# P8             0.999890  0.357674  0.633946  0.013225  0.360928 -0.134945
# T8            -0.093887  0.277948  0.536751 -0.702545 -0.213723 -0.320286
# FC6            0.603163  0.238997  0.471109  0.439644  0.736524  0.456100
# F4            -0.476122 -0.157727 -0.275850  0.636683  0.463063  0.762904
# ...

# %%
X = dataset.iloc[:, 0:14].values
y = dataset.iloc[:, 14].values

# %%
#from sklearn importing train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.20, random_state= 0)

# %%
#Scaling using standard scaler
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train= sc.fit_transform(X_train)
X_test= sc.transform(X_test)

# %%
# No.1 logistic regression classifier
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import accuracy_score

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.6153866679521893

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.6211615487316422

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.62      0.75      0.68      1613
#           1       0.62      0.47      0.53      1383
#
# avg / total       0.62      0.62      0.61      2996

# %%
# No 2 K Nearest Neighbors(KNN)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.20, random_state= 0)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train= sc.fit_transform(X_train)
X_test= sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors= 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.863415499856286

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.8634846461949266

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.88      0.87      1613
#           1       0.86      0.85      0.85      1383
#
# avg / total       0.86      0.86      0.86      2996

# %%
# No3 Support Vector Machine (SVM linear kernel)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.623375757800885

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.6295060080106809

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.63      0.77      0.69      1613
#           1       0.64      0.46      0.53      1383
#
# avg / total       0.63      0.63      0.62      2996

# %%
# No4 SVM (sigmoid kernel) classifier

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'sigmoid', random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.5466400214230355

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.5483978638184246

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.61      0.59      1613
#           1       0.51      0.48      0.50      1383
#
# avg / total       0.55      0.55      0.55      2996

# %%
# No 5 Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.8379885091772173

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.8381174899866488

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.86      0.85      1613
#           1       0.83      0.82      0.82      1383
#
# avg / total       0.84      0.84      0.84      2996

# %%
# No6 Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators= 10, criterion = 'entropy', random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# C:\Users\iwx499921\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.8907913573828783

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.8898531375166889

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.94      0.90      1613
#           1       0.92      0.83      0.87      1383
#
# avg / total       0.89      0.89      0.89      2996

# %%
# No7 GaussainNaivebase classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.32517047323844794

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.4606141522029373

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.49      0.05      0.08      1613
#           1       0.46      0.95      0.62      1383
#
# avg / total       0.48      0.46      0.33      2996

# %%
# No.8 Support Vector Machine (SVM Radial basis Function Kernel(RBF) or Gaussian kernel)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.7048883878608212

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.7062750333778371

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.68      0.84      0.76      1613
#           1       0.75      0.55      0.63      1383
#
# avg / total       0.71      0.71      0.70      2996

# %%
# No.9 Support Vector Machine (Polynomial)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'poly', random_state= 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=0, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4, 4))
sns.heatmap(cm, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
fbeta_score(y_test, y_pred, average='weighted', beta=0.5)
# Out:
# 0.4971459790560073

# %%
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.5834445927903872

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.56      1.00      0.72      1613
#           1       0.97      0.10      0.18      1383
#
# avg / total       0.75      0.58      0.47      2996

# %%
#Summary
# No.1 logistic regression classifier accuracy_score=62%
# No.2 K Nearest Neighbors(KNN) accuracy_score=86%
# No.3 Support Vector Machine (linear kernel) accuracy_score=63%
# No.4 Support Vector Machine (sigmoid kernel)  accuracy_score=55%
# No.5 Decision Tree Classification(entropy) accuracy_score=84%
# No.6 Random Forest Classification accuracy_score=89%
# No.7 GaussainNaivebase classifier  accuracy_score=46%
# No.8 Support Vector Machine (RBF(radial basis function kernel) Gaussian Kernel) accuracy_score=71%
# No.9 Support Vector Machine (Polynomial) accuracy_score=58%
